# %%
import pandas as pd

# %% [markdown]
# #working with JSON

# %%
# df = pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')

# %%
# print(df)

# %% [markdown]
# ##Working with SQL

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode	LIKE 'PAK'",conn)
# Out:
# C:\Users\Rocky computer\AppData\Local\Temp\ipykernel_10896\2308314886.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE CountryCode	LIKE 'PAK'",conn)
#       ID              Name CountryCode              District  Population
# 0   2822           Karachi         PAK                 Sindh     9269265
# 1   2823            Lahore         PAK                Punjab     5063499
# 2   2824        Faisalabad         PAK                Punjab     1977246
# 3   2825        Rawalpindi         PAK                Punjab     1406214
# 4   2826            Multan         PAK                Punjab     1182441
# 5   2827         Hyderabad         PAK                 Sindh     1151274
# 6   2828        Gujranwala         PAK                Punjab     1124749
# ...

# %%
pd.read_sql_query("SELECT * FROM country WHERE Continent LIKE 'Oceania'",conn)
# Out:
# C:\Users\Rocky computer\AppData\Local\Temp\ipykernel_10896\3600098414.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country WHERE Continent LIKE 'Oceania'",conn)
#    Code                                  Name Continent  \
# 0   ASM                        American Samoa   Oceania
# 1   AUS                             Australia   Oceania
# 2   CCK               Cocos (Keeling) Islands   Oceania
# 3   COK                          Cook Islands   Oceania
# 4   CXR                      Christmas Island   Oceania
# 5   FJI                          Fiji Islands   Oceania
# 6   FSM       Micronesia, Federated States of   Oceania
# 7   GUM                                  Guam   Oceania
# 8   KIR                              Kiribati   Oceania
# ...

# %%
pd.read_sql_query("SELECT * FROM country WHERE SurfaceArea > 700000",conn)
# Out:
# C:\Users\Rocky computer\AppData\Local\Temp\ipykernel_10896\1946084735.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country WHERE SurfaceArea > 700000",conn)
#    Code                                   Name      Continent  \
# 0   AGO                                 Angola         Africa
# 1   ARG                              Argentina  South America
# 2   ATA                             Antarctica     Antarctica
# 3   AUS                              Australia        Oceania
# 4   BOL                                Bolivia  South America
# 5   BRA                                 Brazil  South America
# 6   CAN                                 Canada  North America
# 7   CHL                                  Chile  South America
# ...
