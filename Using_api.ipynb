# %%
import pandas as pd
import requests

# %%
resp = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')
# Out:
# <Response [200]>

# %%
dd = pd.DataFrame(resp.json()['results'])[['id','title','release_date']]
# Out:
#          id                                          title release_date
# 0   1007757                                        Swapped   2026-05-01
# 1       278                       The Shawshank Redemption   1994-09-23
# 2    936075                                        Michael   2026-04-22
# 3    687163                              Project Hail Mary   2026-03-15
# 4       238                                  The Godfather   1972-03-14
# 5       240                          The Godfather Part II   1974-12-20
# 6       424                               Schindler's List   1993-12-15
# 7   1330021                    Remarkably Bright Creatures   2026-05-07
# 8       389                                   12 Angry Men   1957-04-10
# 9   1383731                                      Protector   2026-02-20
# 10      129                                  Spirited Away   2001-07-20
# 11      155                                The Dark Knight   2008-07-16
# ...

# %%
df = pd.DataFrame()

# %%
for i in range(1, 429):
    resp = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    dd = pd.DataFrame(resp.json()['results'])[['id','title','release_date']]
    
    # 2. Append the small DataFrame (dd) to your Python list (df_list)
    df.append(dd)  

# 3. Concatenate the list into your final DataFrame after the loop finishes
dfa = pd.concat(df_list, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 6
#       2     resp = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
#       3     dd = pd.DataFrame(resp.json()['results'])[['id','title','release_date']]
#       4
#       5     # 2. Append the small DataFrame (dd) to your Python list (df_list)
# ----> 6     df.append(dd)
#       7
#       8 # 3. Concatenate the list into your final DataFrame after the loop finishes
#       9 dfa = pd.concat(df_list, ignore_index=True)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
# ...
